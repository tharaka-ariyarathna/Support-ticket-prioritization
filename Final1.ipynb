# %%
import pandas as pd
import string
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from string import punctuation

# %%
df = pd.read_excel("D:\\Private\\University\\Research\\Data Sets\\Enhanced Data Sets\\Test 2.xlsx")
df
# Out:
#         id  ticketId                   created                  modified lang  \
# 0     1485    135884  2024-03-01T10:19:16.000Z  2024-03-01T10:20:43.709Z   en
# 1     1484    135864  2024-02-29T21:15:29.000Z  2024-03-01T08:51:11.000Z   en
# 2     1459    135534  2024-02-23T09:41:35.000Z  2024-02-29T15:28:59.000Z   en
# 3     1478    135802  2024-02-29T14:20:52.000Z  2024-02-29T15:06:15.000Z   fr
# 4     1479    135803  2024-02-29T14:20:57.000Z  2024-02-29T15:06:10.000Z   en
# ...    ...       ...                       ...                       ...  ...
# 1289    58     62720  2023-05-31T13:53:43.000Z  2023-06-01T09:48:46.000Z  NaN
# 1290    48     59127  2023-05-24T12:42:19.000Z  2023-06-01T09:48:46.000Z  NaN
# 1291   323     62810  2023-05-31T15:53:38.000Z  2023-06-01T09:48:39.000Z  NaN
# 1292    60     62070  2023-05-30T14:52:03.000Z  2023-06-01T09:48:38.000Z  NaN
# 1293    46     62066  2023-05-30T14:49:51.000Z  2023-06-01T09:48:36.000Z  NaN
#
#      channel                              companies  status  \
# 0        web   [{'type': 'account', 'data': '564'}]    open
# 1      email  [{'type': 'account', 'data': '1684'}]  closed
# 2        web  [{'type': 'account', 'data': '1521'}]    open
# 3      email  [{'type': 'account', 'data': '1723'}]  closed
# 4      email  [{'type': 'account', 'data': '1652'}]  closed
# ...      ...                                    ...     ...
# 1289     web   [{'type': 'account', 'data': '192'}]  closed
# 1290     web     [{'type': 'account', 'data': '3'}]  closed
# 1291     web  [{'type': 'account', 'data': '1021'}]  closed
# 1292     web   [{'type': 'account', 'data': '463'}]  closed
# 1293     web   [{'type': 'account', 'data': '343'}]  closed
#
#                                               requester priority  \
# 0                  {'type': 'contact', 'data': '11888'}   urgent
# 1                  {'type': 'contact', 'data': '10331'}      low
# 2                   {'type': 'contact', 'data': '9808'}      low
# 3                  {'type': 'contact', 'data': '10479'}      low
# 4                  {'type': 'contact', 'data': '10259'}      low
# ...                                                 ...      ...
# 1289                {'type': 'contact', 'data': '1150'}      low
# 1290                   {'type': 'contact', 'data': '6'}      low
# 1291  {'type': 'visitor', 'data': 'josephine@seepje....      low
# 1292                {'type': 'contact', 'data': '2360'}      low
# 1293                {'type': 'contact', 'data': '1843'}      low
#
#                                             description    type  \
# 0     <p>can I get an export of all unmapped employe...  ticket
# 1     <div> <p><span style="font-size:8.0pt;font-fam...  ticket
# 2         <p>How to hide managers own salary range </p>  ticket
# 3     <div> <p><span style="font-size:12.0pt;font-fa...  ticket
# 4     <div> <p>﻿<span lang="IT" style="font-size:8.0...  ticket
# ...                                                 ...     ...
# 1289                 <p>Bonjour à l'équipe Figures!</p>  ticket
# 1290  <p>Hi there! I'm trying to change the level fo...  ticket
# 1291  <p>Hooi! Francien the last People &amp; Cultur...  ticket
# 1292  <p>Hi Team, </p>\n<p>Is it possible to get acc...  ticket
# 1293  <p>Hi there, I'd like to set up a call to talk...  ticket
#
#                                                 subject  \
# 0                                                   NaN
# 1     Automatic reply: 10 Compensation Review Mistak...
# 2                                                   NaN
# 3     Réponse automatique : [EXTERNAL] 10 Compensati...
# 4     Risposta automatica: 10 Compensation Review Mi...
# ...                                                 ...
# 1289                                                NaN
# 1290                                                NaN
# 1291                                                NaN
# 1292                                                NaN
# 1293                                                NaN
#
#                                               assigners  \
# 0                                                   NaN
# 1                                                   NaN
# 2                    [{'type': 'admin', 'data': '108'}]
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1289  [{'type': 'visitor', 'data': 'rebecca.madden@f...
# 1290  [{'type': 'visitor', 'data': 'rebecca.madden@f...
# 1291  [{'type': 'visitor', 'data': 'rebecca.madden@f...
# 1292  [{'type': 'visitor', 'data': 'rebecca.madden@f...
# 1293  [{'type': 'visitor', 'data': 'rebecca.madden@f...
#
#                                             attachments
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     [{'fileId': '51203', 'externalId': 'a530bf0b-c...
# ...                                                 ...
# 1289                                                NaN
# 1290                                                NaN
# 1291                                                NaN
# 1292                                                NaN
# 1293                                                NaN
#
# [1294 rows x 15 columns]
